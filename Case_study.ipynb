# %% [markdown]
# <a href="https://colab.research.google.com/github/kiransree2002/Assessment/blob/main/Case_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Bank Account(deposit, withdrawal, and balance)

# %%
#Bank Account(deposit, withdrawal, and balance)
Account_Name = "Kiran"
Account_Number = 10325468745213
Current_Balance = 10000
print(">>>>WELCOME FEDERAL BANK<<<<")
print("Account Name : ",Account_Name)
print("Account Number :",Account_Number)
print("Current Balance : ",Current_Balance)

def main_bank(deposit,withdrawal,balance):    #main fuction for depositing,withdrawing and balance
  Balance_amount = deposit + Current_Balance
  print("deposit_amount : ",Balance_amount) #balancing showing

  if withdrawal > Current_Balance:
    print("You donot have an sufficient bank balance")
  else:
    amount = Current_Balance - withdrawal_amount
    print("withdrawal amount :",amount)


def main(bank):
  main_bank = bank
# Out:
# >>>>WELCOME FEDERAL BANK<<<<
# Account Name :  Kiran
# Account Number : 10325468745213
# Current Balance :  10000

# %% [markdown]
# #Weather Data Analyzer

# %%
#Weather Data Analyzer
import numpy as np

def average_temperature_humidity(temp,hum):
  np = [32,46,12,25,31,25]
  hum = [45,16,32,59,41,36]
  avg_temp = np.mean()
  avg_hum = hum.average()
  print(avg_temp)

def
