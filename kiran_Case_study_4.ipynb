# %% [markdown]
# <a href="https://colab.research.google.com/github/kiransree2002/Assessment/blob/main/kiran_Case_study_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###importing Libraries

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
import time

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim

# %%
filepath = '/content/adult_dataset (1).csv'
df = pd.read_csv(filepath)
df.head()
# Out:
#     age         workclass  fnlwgt  education  education-num  \
# 0  39.0         State-gov   77516  Bachelors             13
# 1  50.0  Self-emp-not-inc   83311  Bachelors             13
# 2  38.0           Private  215646    HS-grad              9
# 3  53.0           Private  234721       11th              7
# 4  28.0           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country income
# 0          2174             0            40.0            NaN  <=50K
# 1             0             0            13.0  United-States  <=50K
# 2             0             0            40.0  United-States  <=50K
# 3             0             0            40.0  United-States  <=50K
# 4             0             0            40.0           Cuba  <=50K

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             46400 non-null  float64
#  1   workclass       45480 non-null  object
#  2   fnlwgt          48842 non-null  int64
#  3   education       48842 non-null  object
#  4   education-num   48842 non-null  int64
#  5   marital-status  48842 non-null  object
#  6   occupation      45485 non-null  object
#  7   relationship    48842 non-null  object
#  8   race            48842 non-null  object
#  9   sex             48842 non-null  object
#  10  capital-gain    48842 non-null  int64
#  11  capital-loss    48842 non-null  int64
#  12  hours-per-week  46400 non-null  float64
#  13  native-country  46137 non-null  object
#  14  income          48842 non-null  object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  46400.000000  4.884200e+04   48842.000000  48842.000000  48842.000000
# mean      38.679116  1.896641e+05      10.078089   1079.067626     87.502314
# std       13.952954  1.056040e+05       2.570973   7452.019058    403.004552
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.175505e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.781445e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.376420e+05      12.000000      0.000000      0.000000
# max      255.000000  1.490400e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    46400.000000
# mean        40.448599
# std         12.646992
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max        250.000000

# %% [markdown]
# ###Check Missing Values

# %%
df.isnull().sum()
# Out:
# age               2442
# workclass         3362
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        3357
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week    2442
# native-country    2705
# income               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(16)

# %%
# Cell C: handle missing values (THIS MUST COME BEFORE ENCODING)
df['income'] = df['income'].str.replace('.', '', regex=False)
df.replace('?', np.nan, inplace=True)
df.dropna(inplace=True)

print(df.isnull().sum().sum())
print(df['income'].unique())
# Out:
# 0
# ['<=50K' '>50K']

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ###Encoding

# %%
cat_cols = df.select_dtypes(include='object').columns

print(cat_cols)
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'income'],
#       dtype='object')

# %%
cat_cols = df.select_dtypes(include='object').columns
le = LabelEncoder()
for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# %%
le = LabelEncoder()

for col in cat_cols:
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#     age  workclass  fnlwgt  education  education-num  marital-status  \
# 1  50.0          4   83311          9             13               2
# 2  38.0          2  215646         11              9               0
# 3  53.0          2  234721          1              7               2
# 4  28.0          2  338409          9             13               2
# 5  37.0          2  284582         12             14               2
#
#    occupation  relationship  race  sex  capital-gain  capital-loss  \
# 1           3             0     4    1             0             0
# 2           5             1     4    1             0             0
# 3           5             0     2    1             0             0
# 4           9             5     2    0             0             0
# 5           3             5     4    0             0             0
#
#    hours-per-week  native-country  income
# 1            13.0              38       0
# 2            40.0              38       0
# 3            40.0              38       0
# 4            40.0               4       0
# 5            40.0              38       0

# %% [markdown]
# ###Split Features and Target

# %%
#splitting to target and features
y=df['income']            #target
x=df.drop(columns=['income'],axis=1) #features
#splitting into test train data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=33)

# %% [markdown]
# ###scaling

# %%
scaler = StandardScaler()

X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
# TensorFlow model
tf_model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(x_train.shape[1],)),
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
tf_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
start_time = time.perf_counter()
history = tf_model.fit(x_train, y_train, epochs=50, batch_size=32,
                        validation_split=0.2, verbose=1)
end_time = time.perf_counter()
print(f"Training Time: {end_time - start_time:.4f} seconds")
# Out:
# Epoch 1/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6712 - loss: 159.6743 - val_accuracy: 0.7879 - val_loss: 41.7061
# Epoch 2/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6734 - loss: 146.5889 - val_accuracy: 0.7833 - val_loss: 64.6462
# Epoch 3/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6792 - loss: 119.7776 - val_accuracy: 0.7775 - val_loss: 41.9296
# Epoch 4/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.6797 - loss: 141.5398 - val_accuracy: 0.7818 - val_loss: 186.6725
# Epoch 5/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6818 - loss: 96.5812 - val_accuracy: 0.2486 - val_loss: 176.8940
# Epoch 6/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.6760 - loss: 100.9417 - val_accuracy: 0.7918 - val_loss: 64.5460
# Epoch 7/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.
50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7933 - loss: 0.5156 - val_accuracy: 0.7927 - val_loss: 0.5175
# Epoch 35/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7930 - loss: 0.5070 - val_accuracy: 0.7933 - val_loss: 0.5104
# Epoch 36/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7927 - loss: 0.5032 - val_accuracy: 0.7893 - val_loss: 0.5117
# Epoch 37/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7925 - loss: 0.5028 - val_accuracy: 0.7922 - val_loss: 0.5100
# Epoch 38/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7929 - loss: 0.5030 - val_accuracy: 0.7920 - val_loss: 0.5094
# Epoch 39/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7923 - loss: 0.5034 - val_accuracy: 0.7910 - val_loss: 0.5113
# Epoch 40/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7920 - loss: 0.5046 - val_accuracy: 0.7913 - val_loss: 0.5182
# Epoch 41/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7805 - loss: 0.5296 - val_accuracy: 0.7598 - val_loss: 0.5637
# Epoch 42/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7790 - loss: 0.5282 - val_accuracy: 0.7827 - val_loss: 0.5193
# Epoch 43/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7878 - loss: 0.5114 - val_accuracy: 0.7890 - val_loss: 0.5189
# Epoch 44/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7832 - loss: 0.5186 - val_accuracy: 0.7886 - val_loss: 0.5124
# Epoch 45/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7807 - loss: 0.5248 - val_accuracy: 0.7550 - val_loss: 0.5577
# Epoch 46/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7589 - loss: 0.5519 - val_accuracy: 0.7550 - val_loss: 0.5560
# Epoch 47/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7589 - loss: 0.5515 - val_accuracy: 0.7550 - val_loss: 0.5559
# Epoch 48/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7589 - loss: 0.5515 - val_accuracy: 0.7550 - val_loss: 0.5558
# Epoch 49/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7589 - loss: 0.5515 - val_accuracy: 0.7550 - val_loss: 0.5558
# Epoch 50/50
# 699/699 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7589 - loss: 0.5515 - val_accuracy: 0.7550 - val_loss: 0.5558
# Training Time: 64.4378 seconds

# %%
loss, accuracy = tf_model.evaluate(x_test, y_test)
print("accuracy:", accuracy)
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7528 - loss: 0.5582
# accuracy: 0.7527896761894226

# %% [markdown]
# ##PyTorch

# %%
# Cell 22 correction
x_train_tensor = torch.FloatTensor(X_train)
x_test_tensor = torch.FloatTensor(X_test)
y_train_tensor = torch.FloatTensor(y_train.values.reshape(-1,1))
y_test_tensor = torch.FloatTensor(y_test.values.reshape(-1,1))

# %%
import torch
import torch.nn as nn

class ANN(nn.Module):
    def __init__(self, input_dim):
        super().__init__()

        self.network = nn.Sequential(
            nn.Linear(input_dim, 64),
            nn.ReLU(),
            nn.Linear(64, 32),
            nn.ReLU(),
            nn.Linear(32, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        return self.network(x)

# %%
model = ANN(input_dim=x_train_tensor.shape[1])

# %%
criterion = nn.BCELoss()

# %%
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
start_time = time.perf_counter()
epochs = 50
for epoch in range(epochs):
  outputs = model(x_train_tensor)
  loss = criterion(outputs, y_train_tensor)
  optimizer.zero_grad()
  loss.backward()
  optimizer.step()
  if (epoch+1) % 10 == 0:
    print(f'Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}')
end_time = time.perf_counter()
print(f"Training time: {end_time-start_time:.4f}seconds")
# Out:
# Epoch [10/50], Loss: 0.6631
# Epoch [20/50], Loss: 0.5983
# Epoch [30/50], Loss: 0.5392
# Epoch [40/50], Loss: 0.4946
# Epoch [50/50], Loss: 0.4628
# Training time: 1.0957seconds
